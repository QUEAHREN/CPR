# %%
import cv2
import os
from matplotlib import pyplot as plt
from predict_unet import *
from PIL import Image, ImageDraw

# data_path = "/media/queahren/DATA/DATA_A28_same/"
# save_path = "/media/queahren/DATA/DATA_A28_same/result/"

data_path = "/media/queahren/DATA/testData/测试数据/"
save_path = "/media/queahren/DATA/testData/测试数据/result/"

base_dir = data_path + "images"
filename = os.listdir(base_dir)
base_dir = data_path + "/"
font=cv2.FONT_HERSHEY_SIMPLEX

count = 0
for imgname in filename:
    if(imgname.endswith('.png')):
        count += 1
        print(imgname, count/len(filename))
        predict_unet(data_path, imgname, save_path)
# Out:
# line_105.png 0.001
# using cuda:0 device.
# inference+NMS time: 0.014550447463989258
# curve_0.png 0.002
# using cuda:0 device.
# inference+NMS time: 0.020098209381103516
# curve_1.png 0.003
# using cuda:0 device.
# inference+NMS time: 0.014683008193969727
# curve_10.png 0.004
# using cuda:0 device.
# inference+NMS time: 0.015500307083129883
# curve_100.png 0.005
# using cuda:0 device.
# inference+NMS time: 0.013930559158325195
# curve_101.png 0.006
# using cuda:0 device.
# inference+NMS time: 0.013875722885131836
# curve_102.png 0.007
# using cuda:0 device.
# inference+NMS time: 0.013891220092773438
# curve_103.png 0.008
# using cuda:0 device.
# inference+NMS time: 0.049814701080322266
# curve_104.png 0.009
# using cuda:0 device.
# inference+NMS time: 0.012063741683959961
# curve_105.png 0.01
# using cuda:0 device.
# inference+NMS time: 0.014423370361328125
# curve_106.png 0.011
# using cuda:0 device.
# inference+NMS time: 0.013946056365966797
# curve_107.png 0.012
# ...
